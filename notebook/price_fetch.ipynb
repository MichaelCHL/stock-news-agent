# %%
from dotenv import load_dotenv
import finnhub
import os
import httpx

load_dotenv()
# Out:
# True

# %%
FINNHUB_API_KEY = os.getenv("FINNHUB_API_KEY")

# %%
finnhub_cliet = finnhub.Client(api_key=FINNHUB_API_KEY)

# %%
finnhub_cliet.quote(symbol='SPY')
# Out:
# {'c': 648.57,
#  'd': -11.23,
#  'dp': -1.702,
#  'h': 656.69,
#  'l': 644.72,
#  'o': 656.51,
#  'pc': 659.8,
#  't': 1774036800}

# %%
client  = httpx.AsyncClient()
spy = httpx.get(f"https://finnhub.io/api/v1/quote?symbol=SPY&token={FINNHUB_API_KEY}")

# %%
spy
# Out:
# <Response [200 OK]>

# %%
spy.json()
# Out:
# {'c': 711.69,
#  'd': -3.48,
#  'dp': -0.4866,
#  'h': 712.88,
#  'l': 709.25,
#  'o': 711.815,
#  'pc': 715.17,
#  't': 1777406400}
