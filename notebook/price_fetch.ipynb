# %%
from dotenv import load_dotenv
import finnhub
import os

load_dotenv()
# Out:
# True

# %%
FINNHUB_API_KEY = os.getenv("FINNHUB_API_KEY")

# %%
finnhub_cliet = finnhub.Client(api_key=FINNHUB_API_KEY)

# %%
finnhub_cliet.quote(symbol='SPY')
# Out:
# {'c': 648.57,
#  'd': -11.23,
#  'dp': -1.702,
#  'h': 656.69,
#  'l': 644.72,
#  'o': 656.51,
#  'pc': 659.8,
#  't': 1774036800}
